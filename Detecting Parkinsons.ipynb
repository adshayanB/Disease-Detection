# %% [markdown]
# <h1> Import Libraries/Packages</h1>

# %%
import numpy as np
import pandas as pd
import os, sys
import sys




from sklearn.preprocessing import MinMaxScaler
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# <h1>Reading the Data Set</h1>

# %%
df = pd.read_csv ('parkinsons.data.csv')
#df.head()
df
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4    phon_R01_S01_5      116.014       141.781       110.655         0.01284
# ..              ...          ...           ...           ...             ...
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1             0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2             0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3             0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4             0.00011   0.00655   0.00908     0.01966       0.06425  ...
# ..                ...       ...       ...         ...           ...  ...
# 190           0.00003   0.00263   0.00259     0.00790       0.04087  ...
# 191           0.00003   0.00331   0.00292     0.00994       0.02751  ...
# 192           0.00008   0.00624   0.00564     0.01873       0.02308  ...
# 193           0.00004   0.00370   0.00390     0.01109       0.02296  ...
# 194           0.00003   0.00295   0.00317     0.00885       0.01884  ...
#
#      Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 0        0.06545  0.02211  21.033       1  0.414783  0.815285 -4.813031
# 1        0.09403  0.01929  19.085       1  0.458359  0.819521 -4.075192
# 2        0.08270  0.01309  20.651       1  0.429895  0.825288 -4.443179
# 3        0.08771  0.01353  20.644       1  0.434969  0.819235 -4.117501
# 4        0.10470  0.01767  19.649       1  0.417356  0.823484 -3.747787
# ..           ...      ...     ...     ...       ...       ...       ...
# 190      0.07008  0.02764  19.517       0  0.448439  0.657899 -6.538586
# 191      0.04812  0.01810  19.147       0  0.431674  0.683244 -6.195325
# 192      0.03804  0.10715  17.883       0  0.407567  0.655683 -6.787197
# 193      0.03794  0.07223  19.020       0  0.451221  0.643956 -6.744577
# 194      0.03078  0.04398  21.209       0  0.462803  0.664357 -5.724056
#
#       spread2        D2       PPE
# 0    0.266482  2.301442  0.284654
# 1    0.335590  2.486855  0.368674
# 2    0.311173  2.342259  0.332634
# 3    0.334147  2.405554  0.368975
# 4    0.234513  2.332180  0.410335
# ..        ...       ...       ...
# 190  0.121952  2.657476  0.133050
# 191  0.129303  2.784312  0.168895
# 192  0.158453  2.679772  0.131728
# 193  0.207454  2.138608  0.123306
# 194  0.190667  2.555477  0.148569
#
# [195 rows x 24 columns]

# %% [markdown]
# <h1>Get Values and Status</h1>

# %%
data =df.loc[:,df.columns!='status'].values[:,1:]
labels = df.loc[:,'status'].values
labels
print (data)
# Out:
# [[119.992 157.302 74.997 ... 0.266482 2.3014419999999998 0.284654]
#  [122.4 148.65 113.819 ... 0.33559 2.486855 0.368674]
#  [116.682 131.111 111.555 ... 0.311173 2.342259 0.33263400000000004]
#  ...
#  [174.688 240.005 74.287 ... 0.158453 2.6797720000000003
#   0.13172799999999998]
#  [198.764 396.961 74.904 ... 0.207454 2.138608 0.123306]
#  [214.289 260.277 77.973 ... 0.190667 2.555477 0.148569]]

# %% [markdown]
# <h1>Count of Diagonsis</h1>

# %%
# print(labels[labels==1].shape[0], labels[labels==0].shape[0])
df.groupby('status').size()
# Out:
# status
# 0     48
# 1    147
# dtype: int64

# %% [markdown]
# <h1>Scale the Values to be between -1 and 1</h1>

# %%
scaler = MinMaxScaler((-1,1))
x=scaler.fit_transform(data)
y=labels

# %% [markdown]
# <h1>Split the Data Set</h1>

# %%
x_train,x_test,y_train,y_test = train_test_split (x,y,test_size=0.10,random_state=7)

# %% [markdown]
# <h1>Train the Model</h1>

# %%
parkinsons_model = XGBClassifier()
history = parkinsons_model.fit(x_train,y_train)

# %% [markdown]
# <h1>Prediciting using Test Data </h1>

# %%
y_test_Probablity = parkinsons_model.predict_proba(x_test)
# X=[ 0.33082225  0.89266869  0.28711412 -0.07306226 -0.4229249  -0.18015414
#  -0.0664523  -0.18060684  0.13492788  0.22925226  0.17873652  0.0027137
#  -0.12075963  0.17884196 -0.50192571 -0.46777209 -0.20175183  0.60494968
#   0.11101613  0.15261616  0.32296558 -0.06536489], Predicted=[0.0054608 0.9945392], Decision=1, Correct Diagonsis=1
# X=[ 0.83006544 -0.34701001  0.91569081 -0.95743329 -0.97628458 -0.94315992
#  -0.93997856 -0.94349013 -0.88059156 -0.90797042 -0.82627119 -0.88955224
#  -0.93414503 -0.82603672 -0.97383582  0.31358205 -0.01573332 -0.54287149
#  -0.70749779 -0.45356682 -0.13799654 -0.781301  ], Predicted=[0.99247587 0.00752415], Decision=0, Correct Diagonsis=0
# X=[-0.66617377 -0.82722067 -0.60335993 -0.88246506 -0.81818182 -0.89595376
#  -0.86495177 -0.89597046 -0.87164506 -0.90139688 -0.83590139 -0.86648575
#  -0.9082625  -0.83579407 -0.9665786   0.38210193 -0.38909098  0.45175813
#  -0.29400051  0.00411734 -0.59992402 -0.50881473], Predicted=[0.60170686 0.39829317], Decision=0, Correct Diagonsis=0
# X=[ 0.10829472 -0.53185339  0.10382627 -0.17534943 -0.4229249  -0.24759152
#  -0.22079314 -0.24803339 -0.06956363 -0.1240756  -0.07164869 -0.04179104
#  -0.13622789 -0.07163949 -0.61855047 -0.51832886  0.03342892  0.55129359
#   0.33372278  0.5733771   0.52951775  0.20765987], Predicted=[0.00168121 0.9983188 ], Decision=1, Correct Diagonsis=1

# %% [markdown]
# <h1>Accuracy</h1>

# %%
print (accuracy_score(y_test, y_predict)*100)
# Out:
# 95.0

# %% [markdown]
# <h1>Comparing Diagnosis<h1>

# %%
columns = list(df.columns.values.tolist())
#columns =columns[1:17].append(columns[18:23])
columns.remove('status')
columns.remove('name')

new_data = pd.DataFrame(x_test,columns =columns, index = range(0,20))


#new_data["Doctor Diagnosis"] = y_test

#new_data["Machine Diagonis"]= y_predict

new_data.insert(0,'Doctor Diagnosis',y_test)
new_data.insert(1,'Machine Diagnosis',y_predict)
new_data[['0 PRB','1 PRB']]=pd.DataFrame(y_test_Probablity)

df1 = new_data.pop('1 PRB')
df2 = new_data.pop('0 PRB')

new_data.insert(2,'1 PRB',df1)
new_data.insert(3,'0 PRB',df2)

new_data_visualized = new_data.style.format({"1 PRB":"{:.2%}","0 PRB":"{:.2%}"})
new_data_visualized
# Out:
# <style  type="text/css" >
# </style><table id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Doctor Diagnosis</th>        <th class="col_heading level0 col1" >Machine Diagnosis</th>        <th class="col_heading level0 col2" >1 PRB</th>        <th class="col_heading level0 col3" >0 PRB</th>        <th class="col_heading level0 col4" >MDVP:Fo(Hz)</th>        <th class="col_heading level0 col5" >MDVP:Fhi(Hz)</th>        <th class="col_heading level0 col6" >MDVP:Flo(Hz)</th>        <th class="col_heading level0 col7" >MDVP:Jitter(%)</th>        <th class="col_heading level0 col8" >MDVP:Jitter(Abs)</th>        <th class="col_heading level0 col9" >MDVP:RAP</th>        <th class="col_heading level0 col10" >MDVP:PPQ</th>        <th class="col_heading level0 col11" >Jitter:DDP</th>        <th class="col_heading level0 col12" >MDVP:Shimmer</th>        <th class="col_heading level0 col13" >MDVP:Shimmer(dB)</th>        <th class="col_heading level0 col14" >Shimmer:APQ3</th>        <th class="col_heading level0 col15" >Shimmer:APQ5</th>        <th class="col_heading level0 col16" >MDVP:APQ</th>        <th class="col_heading level0 col17" >Shimmer:DDA</th>        <th class="col_heading level0 col18" >NHR</th>        <th class="col_heading level0 col19" >HNR</th>        <th class="col_heading level0 col20" >RPDE</th>        <th class="col_heading level0 col21" >DFA</th>        <th class="col_heading level0 col22" >spread1</th>        <th class="col_heading level0 col23" >spread2</th>        <th class="col_heading level0 col24" >D2</th>        <th class="col_heading level0 col25" >PPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col2" class="data row0 col2" >80.95%</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col3" class="data row0 col3" >19.05%</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col4" class="data row0 col4" >0.410975</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col5" class="data row0 col5" >-0.384051</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col6" class="data row0 col6" >-0.723514</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col7" class="data row0 col7" >-0.748412</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col8" class="data row0 col8" >-0.818182</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col9" class="data row0 col9" >-0.746628</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col10" class="data row0 col10" >-0.785638</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col11" class="data row0 col11" >-0.746348</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col12" class="data row0 col12" >-0.671901</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col13" class="data row0 col13" >-0.707477</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col14" class="data row0 col14" >-0.557396</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col15" class="data row0 col15" >-0.705020</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col16" class="data row0 col16" >-0.822345</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col17" class="data row0 col17" >-0.557324</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col18" class="data row0 col18" >-0.888914</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col19" class="data row0 col19" >-0.129806</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col20" class="data row0 col20" >-0.182866</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col21" class="data row0 col21" >-0.131798</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col22" class="data row0 col22" >-0.360089</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col23" class="data row0 col23" >-0.446089</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col24" class="data row0 col24" >0.210947</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row0_col25" class="data row0 col25" >-0.484885</td>
#             </tr>
#             <tr>
#                         <th id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row1_col2" class="data row1 col2" >92.13%</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row1_col3" class="data row1 col3" >7.87%</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row1_col4" class="data row1 col4" >-0.527199</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row1_col5" class="data row1 col5" >0.541390</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row1_col6" class="data row1 col6" >-0.737757</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row1_col7" class="data row1 col7" >-0.737611</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row1_col8" class="data row1 col8" >-0.660079</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row1_col9" class="data row1 col9" >-0.833333</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row1_col10" class="data row1 col10" >-0.762058</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row1_col11" class="data row1 col11" >-0.833360</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row1_col12" class="data row1 col12" >-0.807559</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row1_col13" class="data row1 col13" >-0.776500</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row1_col14" class="data row1 col14" >-0.848228</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row1_col15" class="data row1 col15" >-0.851560</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row1_col16" class="data row1 col16" >-0.844552</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row1_col17" class="data row1 col17" >-0.847991</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row1_col18" class="data row1 col18" >-0.854537</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row1_col19" class="data row1 col19" >0.325043</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row1_col20" class="data row1 col20" >0.078844</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row1_col21" class="data row1 col21" >-0.124738</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row1_col22" class="data row1 col22" >-0.356763</td>
#                         <td id="T_17973a68_55ae_11ea_a85c_8c85901b0ae4row1_col23" class="dat

# %% [markdown]
# <h1>Discrepancy Data</h1>

# %%
discrepancy = new_data.loc[(new_data['Doctor Diagnosis'])!=(new_data['Machine Diagnosis'])]
discrepancy
# Out:
#    Doctor Diagnosis  Machine Diagnosis     1 PRB     0 PRB  MDVP:Fo(Hz)  \
# 0                 0                  1  0.809528  0.190472     0.410975
#
#    MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  MDVP:RAP  \
# 0     -0.384051     -0.723514       -0.748412         -0.818182 -0.746628
#
#    ...  MDVP:APQ  Shimmer:DDA       NHR       HNR      RPDE       DFA  \
# 0  ... -0.822345    -0.557324 -0.888914 -0.129806 -0.182866 -0.131798
#
#     spread1   spread2        D2       PPE
# 0 -0.360089 -0.446089  0.210947 -0.484885
#
# [1 rows x 26 columns]
